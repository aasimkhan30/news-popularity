# %% [markdown]
# #This notebook contains some data analysis done on the preprocessed csv file
# 1. Converted this Regression problem into classification by predicting where the news will be popular or not.
# 2. Popular News are those that get over 1400 shares.
# 3. These news are denoted by a 1 and the unpopular onces are denoted by 0
# 4. A very strange problem in the dataset is that the each column label contains a whitespace so have to be referred by ' column_lable' instead of 'column_label'

# %% [markdown]
# importing necessary packages

# %%
 import pandas as pd
 import numpy as np
 import keras

# %%
df = pd.read_csv('data/data2.csv')

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>n_tokens_title</th>
#       <th>n_tokens_content</th>
#       <th>n_unique_tokens</th>
#       <th>n_non_stop_words</th>
#       <th>n_non_stop_unique_tokens</th>
#       <th>num_hrefs</th>
#       <th>num_self_hrefs</th>
#       <th>num_imgs</th>
#       <th>num_videos</th>
#       <th>...</th>
#       <th>min_positive_polarity</th>
#       <th>max_positive_polarity</th>
#       <th>avg_negative_polarity</th>
#       <th>min_negative_polarity</th>
#       <th>max_negative_polarity</th>
#       <th>title_subjectivity</th>
#       <th>title_sentiment_polarity</th>
# ...

# %% [markdown]
# Creating a simple classification neural net
